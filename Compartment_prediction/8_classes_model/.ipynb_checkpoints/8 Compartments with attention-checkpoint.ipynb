# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import csv
import numpy as np
# %matplotlib inline 
from matplotlib.ticker import MultipleLocator
from sklearn.preprocessing import normalize
import pandas as pd

import os 
from keras.layers import Conv1D, MaxPooling1D
from keras.models import load_model
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight
from keras.utils.vis_utils import plot_model
from keras import initializers
from keras import regularizers
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
# Out:
# Using TensorFlow backend.
# /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
train = pd.read_csv("data/8C_train.csv", sep="\t")
valid = pd.read_csv("data/8C_valid.csv", sep="\t")

y_train = train["Compartment Prediction"]
y_valid = valid["Compartment Prediction"]

x_train = train["Sequence"].copy()
x_valid = valid["Sequence"].copy()

# %%
print(len(x_train), 'train sequences')
print(len(x_valid), 'test sequences')
# Out:
# 3022 train sequences
# 756 test sequences

# %%
max_len = len(max(x_train, key=len))
print(max_len)
# Out:
# 1500

# %%
# all amino acids (in blosum order)
aa = "*ARNDCQEGHILKMFPSTWYVU"
tot_aa = len(aa)

# define a mapping of aa to integers
aa_to_int = dict((c, i) for i, c in enumerate(aa))
int_to_aa = dict((i, c) for i, c in enumerate(aa))

# %% [markdown]
# ## One hot encoding of Labels

# %%
set(y_train)
# Out:
# {'Actin binding proteins',
#  'ER',
#  'Endosome',
#  'Golgi',
#  'Large Protein Complex',
#  'Lysosome',
#  'Mitochondrion',
#  'Plasma membrane'}

# %%
cat = list(set(y_train))
cat
# Out:
# ['Mitochondrion',
#  'Endosome',
#  'Plasma membrane',
#  'Golgi',
#  'Large Protein Complex',
#  'ER',
#  'Lysosome',
#  'Actin binding proteins']

# %%
cat = ['Actin binding proteins',
 'ER',
 'Endosome',
 'Ergic/cisGolgi',
 'Golgi',
 'Large Protein Complex',
 'Lysosome',
 'Mitochondrion',
 'Plasma membrane']

tot_cat = len(cat)
cat_to_int = {}
int_to_cat = {}
for i in range(tot_cat):
    cat_to_int[cat[i]] = i
    int_to_cat[i] = cat[i]

# %%
def cat_to_indices(Y):
    Y_indices = np.zeros([Y.shape[0],], dtype=int)
    for i in range(len(Y)):
        Y_indices[i] = cat_to_int[Y[i]]
    return Y_indices

# one hot encode
def convert_to_one_hot(Y, C):
    Y = np.eye(C)[Y.reshape(-1)]
    return Y

# %%
y_train_indices = cat_to_indices(y_train)
y_valid_indices = cat_to_indices(y_valid)

y_train_OH = convert_to_one_hot(y_train_indices, C = tot_cat)
y_valid_OH = convert_to_one_hot(y_valid_indices, C = tot_cat)

# %% [markdown]
# ## X_train processing:
# ### From Sequences to list of indices

# %%
# Function to convert sequences to array of indices. I will that that one for embedding 

def seq_to_indices(X, aa_to_int, max_len):
    
    m = X.shape[0]                                   # number of training examples
    
    ### START CODE HERE ###
    # Initialize X_indices as a numpy matrix of zeros and the correct shape (≈ 1 line)
    X_indices = []
    
    for i in range(m):                               # loop over training examples
        seq_aa = X[i]
        seq_ind = []
        
        # Loop over the words of sentence_words
        for w in range(len(seq_aa)):
            seq_ind.append(aa_to_int[seq_aa[w]])
            
        X_indices.append(seq_ind)
            
    ### END CODE HERE ###
    
    return X_indices

# %%
x_train_indices = seq_to_indices(x_train, aa_to_int, max_len)
x_valid_indices = seq_to_indices(x_valid, aa_to_int, max_len)

# %%
# Pad sequences
# By default, the padding is added before the sequence
x_train_pad = sequence.pad_sequences(x_train_indices, maxlen=max_len, value=aa_to_int["*"])
x_valid_pad = sequence.pad_sequences(x_valid_indices, maxlen=max_len, value=aa_to_int["*"])
print('x_train shape:', x_train_pad.shape)
print('x_valid shape:', x_valid_pad.shape)
# Out:
# x_train shape: (3066, 1499)
# x_valid shape: (767, 1499)

# %%
# One hot to label 
#Y is list of OH vector
def OH_to_label_indices(Y):
    labels = []
    for a in Y:
        indices = np.argmax(a)
        labels.append(indices)
    return labels

# %%
def indices_to_cat(Y):
    Y_cat = []
    for i in range(len(Y)):
        Y_cat.append(int_to_cat[Y[i]])
    return Y_cat

# %% [markdown]
# ## Training and testing models

# %% [markdown]
# ### Bidirectional LSTM with simple Attention Layer

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
d_class_weights = dict(enumerate(class_weights))

# %%
max_features = tot_aa + 1
batch_size = 64
embedding_size = 128
units = 128

_input = Input(shape=[max_len], dtype='int32')

# get the embedding layer
embedded = Embedding(
        input_dim=max_features,
        output_dim=embedding_size,
        input_length=max_len,
        trainable=True,
        mask_zero=False
    )(_input)

activations = Bidirectional(LSTM(units, return_sequences=True, 
                                 dropout=0.2, recurrent_dropout=0.2))(embedded)

# compute importance for each step
attention = Dense(1, activation='tanh')(activations)
attention = Flatten()(attention)
attention = Activation('softmax', name = 'attention_vect')(attention) # attention_vect for visualization
attention = RepeatVector(units*2)(attention)
attention = Permute([2, 1])(attention)
sent_representation = Multiply()([activations, attention])
sent_representation = Lambda(lambda xin: K.sum(xin, axis=-2), output_shape=(units*2,))(sent_representation)

probabilities = Dense(9, activation='softmax')(sent_representation)
# Out:
# WARNING:tensorflow:From /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model = Model(inputs=_input, outputs=probabilities)
model.compile('Nadam', 'categorical_crossentropy', metrics=['accuracy'])
ckpt = ModelCheckpoint(filepath='models_attention/1/weights.{epoch:02d}-{val_loss:.2f}.hdf5', 
                           verbose=1, save_best_only=False)
# Train, train, train
history = model.fit(x_train_pad, y_train_OH, 
                    batch_size=batch_size, epochs=50,
                    class_weight = class_weights,
          validation_data=[x_valid_pad, y_valid_OH], callbacks=[ckpt])
# Out:
# WARNING:tensorflow:From /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 3066 samples, validate on 767 samples
# Epoch 1/50
# 3066/3066 [==============================] - 404s 132ms/step - loss: 1.6431 - accuracy: 0.4997 - val_loss: 1.5884 - val_accuracy: 0.5033
#
# Epoch 00001: saving model to models_attention/1/weights.01-1.59.hdf5
# Epoch 2/50
# 3066/3066 [==============================] - 309s 101ms/step - loss: 1.5697 - accuracy: 0.5029 - val_loss: 1.5605 - val_accuracy: 0.5033
#
# Epoch 00002: saving model to models_attention/1/weights.02-1.56.hdf5
# Epoch 3/50
# 3066/3066 [==============================] - 352s 115ms/step - loss: 1.5498 - accuracy: 0.5007 - val_loss: 1.5297 - val_accuracy: 0.5033
#
# Epoch 00003: saving model to models_attention/1/weights.03-1.53.hdf5
# Epoch 4/50
# 3066/3066 [==============================] - 365s 119ms/step - loss: 1.4891 - accuracy: 0.5144 - val_loss: 1.4413 - val_accuracy: 0.5319
#
# Epoch 00004: saving model to models_attention/1/weights.04-1.44.hdf5
# Epoch 5/50
# 3066/3066 [==============================] - 370s 121ms/step - loss: 1.4413 - accuracy: 0.5297 - val_loss: 1.4186 - val_accuracy: 0.5502
#
# Epoch 00005: saving model to models_attention/1/weights.05-1.42.hdf5
# Epoch 6/50
# 3066/3066 [==============================] - 310s 101ms/step - loss: 1.3662 - accuracy: 0.5561 - val_loss: 1.4212 - val_accuracy: 0.5567
#
# Epoch 00006: saving model to models_attention/1/weights.06-1.42.hdf5
# Epoch 7/50
# 3066/3066 [==============================] - 330s 108ms/step - loss: 1.3028 - accuracy: 0.5799 - val_loss: 1.3491 - val_accuracy: 0.5750
#
# Epoch 00007: saving model to models_attention/1/weights.07-1.35.hdf5
# Epoch 8/50
# 3066/3066 [==============================] - 306s 100ms/step - loss: 1.2918 - accuracy: 0.5868 - val_loss: 1.3105 - val_accuracy: 0.5711
#
# Epoch 00008: saving model to models_attention/1/weights.08-1.31.hdf5
# Epoch 9/50
# 3066/3066 [==============================] - 307s 100ms/step - loss: 1.2753 - accuracy: 0.5933 - val_loss: 1.3211 - val_accuracy: 0.5815
#
# Epoch 00009: saving model to models_attention/1/weights.09-1.32.hdf5
# Epoch 10/50
# 3066/3066 [==============================] - 309s 101ms/step - loss: 1.2602 - accuracy: 0.6047 - val_loss: 1.3890 - val_accuracy: 0.5854
#
# Epoch 00010: saving model to models_attention/1/weights.10-1.39.hdf5
# Epoch 11/50
# 3066/3066 [==============================] - 309s 101ms/step - loss: 1.2467 - accuracy: 0.6018 - val_loss: 1.2961 - val_accuracy: 0.6102
#
# Epoch 00011: saving model to models_attention/1/weights.11-1.30.hdf5
# Epoch 12/50
# 3066/3066 [==============================] - 306s 100ms/step - loss: 1.2249 - accuracy: 0.6174 - val_loss: 1.2295 - val_accuracy: 0.6284
#
# Epoch 00012: saving model to models_attention/1/weights.12-1.23.hdf5
# Epoch 13/50
# 3066/3066 [==============================] - 307s 100ms/step - loss: 1.3244 - accuracy: 0.5884 - val_loss: 1.2669 - val_accuracy: 0.6037
#
# Epoch 00013: saving model to models_attention/1/weights.13-1.27.hdf5
# Epoch 14/50
# 3066/3066 [==============================] - 307s 100ms/step - loss: 1.3027 - accuracy: 0.5848 - val_loss: 1.3436 - val_accuracy: 0.5698
#
# Epoch 00014: saving model to models_attention/1/weights.14-1.34.hdf5
# Epoch 15/50
# 3066/3066 [==============================] - 311s 101ms/step - loss: 1.3489 - accuracy: 0.5597 - val_loss: 1.4094 - val_accuracy: 0.5306
#
# Epoch 00015: saving model to models_attention/1/weights.15-1.41.hdf5
# Epoch 16/50
# 3066/3066 [==============================] - 307s 100ms/step - loss: 1.3837 - accuracy: 0.5479 - val_loss: 1.4227 - val_accuracy: 0.5476
#
# Epoch 00016: saving model to models_attention/1/weights.16-1.42.hdf5
# Epoch 17/50
# 3066/3066 [==============================] - 307s 100ms/step - loss: 1.3281 - accuracy: 0.5721 - val_loss: 1.3301 - val_accuracy: 0.5671
#
# Epoch 00017: saving model to models_attention/1/weights.17-1.33.hdf5
# Epoch 18/50
# 3066/3066 [==============================] - 306s 100ms/step - loss: 1.2826 - accuracy: 0.5848 - val_loss: 1.2956 - val_accuracy: 0.5945
#
# Epoch 00018: saving model to models_attention/1/weights.18-1.30.hdf5
# Epoch 19/50
# 3066/3066 [==============================] - 307s 100ms/step - loss: 1.2831 - accuracy: 0.6044 - val_loss: 1.2721 - val_accuracy: 0.6167
#
# Epoch 00019: saving model to models_attention/1/weights.19-1.27.hdf5
# Epoch 20/50
# 3066/3066 [==============================] - 306s 100ms/step - loss: 1.2306 - accuracy: 0.6246 - val_loss: 1.2528 - val_accuracy: 0.6258
#
# Epoch 00020: saving model to models_attention/1/weights.20-1.25.hdf5
# Epoch 21/50
# 3066/3066 [==============================] - 306s 100ms/step - loss: 1.2180 - accuracy: 0.6327 - val_loss: 1.2989 - val_accuracy: 0.5997
#
# Epoch 00021: saving model to models_attention/1/weights.21-1.30.hdf5
# Epoch 22/50
# 3066/3066 [==============================] - 309s 101ms/step - loss: 1.2440 - accuracy: 0.6093 - val_loss: 1.2144 - val_accuracy: 0.6310
#
# Epoch 00022: saving model to models_attention/1/weights.22-1.21.hdf5
# Epoch 23/50
# 3066/3066 [==============================] - 306s 100ms/step - loss: 1.2020 - accuracy: 0.6288 - val_loss: 1.2396 - val_accuracy: 0.6089
#
# Epoch 00023: saving model to models_attention/1/weights.23-1.24.hdf5
# Epoch 24/50
# 3066/3066 [==============================] - 306s 100ms/step - loss: 1.1860 - accuracy: 0.6406 - val_loss: 1.1960 - val_accuracy: 0.6454
#
# Epoch 00024: saving model to models_attention/1/weights.24-1.20.hdf5
# Epoch 25/50
# 3066/3066 [==============================] - 373s 122ms/step - loss: 1.2057 - accuracy: 0.6230 - val_loss: 1.2202 - val_accuracy: 0.6219
#
# Epoch 00025: saving model to models_attention/1/weights.25-1.22.hdf5
# Epoch 26/50
# 3066/3066 [==============================] - 389s 127ms/step - loss: 1.1470 - accuracy: 0.6523 - val_loss: 1.1615 - val_accuracy: 0.6623
#
# Epoch 00026: saving model to models_attention/1/weights.26-1.16.hdf5
# Epoch 27/50
# 3066/3066 [==============================] - 364s 119ms/step - loss: 1.1428 - accuracy: 0.6539 - val_loss: 1.1982 - val_accuracy: 0.6219
#
# Epoch 00027: saving model to models_attention/1/weights.27-1.20.hdf5
# Epoch 28/50
# 3066/3066 [==============================] - 329s 107ms/step - loss: 1.1274 - accuracy: 0.6556 - val_loss: 1.1917 - val_accuracy: 0.6454
#
# Epoch 00028: saving model to models_attention/1/weights.28-1.19.hdf5
# Epoch 29/50
# 3066/3066 [==============================] - 362s 118ms/step - loss: 1.1440 - accuracy: 0.6386 - val_loss: 1.1964 - val_accuracy: 0.6428
#
# Epoch 00029: saving model to models_attention/1/weights.29-1.20.hdf5
# Epoch 30/50
# 3066/3066 [==============================] - 363s 118ms/step - loss: 1.1302 - accuracy: 0.6461 - val_loss: 1.1938 - val_accuracy: 0.6402
#
# Epoch 00030: saving model to models_attention/1/weights.30-1.19.hdf5
# Epoch 31/50
# 3066/3066 [==============================] - 361s 118ms/step - loss: 1.1143 - accuracy: 0.6660 - val_loss: 1.1564 - val_accuracy: 0.6701
#
# Epoch 00031: saving model to models_attention/1/weights.31-1.16.hdf5
# Epoch 32/50
# 3066/3066 [==============================] - 388s 126ms/step - loss: 1.1066 - accuracy: 0.6654 - val_loss: 1.1421 - val_accuracy: 0.6636
#
# Epoch 00032: saving model to models_attention/1/weights.32-1.14.hdf5
# Epoch 33/50
# 3066/3066 [==============================] - 408s 133ms/step - loss: 1.0836 - accuracy: 0.6804 - val_loss: 1.1172 - val_accuracy: 0.6636
#
# Epoch 00033: saving model to models_attention/1/weights.33-1.12.hdf5
# Epoch 34/50
# 3066/3066 [==============================] - 332s 108ms/step - loss: 1.0775 - accuracy: 0.6689 - val_loss: 1.1411 - val_accuracy: 0.6662
#
# Epoch 00034: saving model to models_attention/1/weights.34-1.14.hdf5
# Epoch 35/50
# 3066/3066 [==============================] - 310s 101ms/step - loss: 1.0857 - accuracy: 0.6735 - val_loss: 1.1400 - val_accuracy: 0.6623
#
# Epoch 00035: saving model to models_attention/1/weights.35-1.14.hdf5
# Epoch 36/50
# 3066/3066 [==============================] - 305s 100ms/step - loss: 1.0697 - accuracy: 0.6794 - val_loss: 1.1395 - val_accuracy: 0.6741
#
# Epoch 00036: saving model to models_attention/1/weights.36-1.14.hdf5
# Epoch 37/50
# 3066/3066 [==============================] - 333s 109ms/step - loss: 1.0589 - accuracy: 0.6898 - val_loss: 1.1354 - val_accuracy: 0.6767
#
# Epoch 00037: saving model to models_attention/1/weights.37-1.14.hdf5
# Epoch 38/50
# 3066/3066 [==============================] - 372s 121ms/step - loss: 1.0429 - accuracy: 0.6879 - val_loss: 1.1331 - val_accuracy: 0.6675
#
# Epoch 00038: saving model to models_attention/1/weights.38-1.13.hdf5
# Epoch 39/50
# 3066/3066 [==============================] - 372s 121ms/step - loss: 1.0523 - accuracy: 0.6898 - val_loss: 1.1107 - val_accuracy: 0.6767
#
# Epoch 00039: saving model to models_attention/1/weights.39-1.11.hdf5
# Epoch 40/50
# 3066/3066 [==============================] - 338s 110ms/step - loss: 1.0355 - accuracy: 0.6941 - val_loss: 1.1101 - val_accuracy: 0.6741
#
# Epoch 00040: saving model to models_attention/1/weights.40-1.11.hdf5
# Epoch 41/50
# 3066/3066 [==============================] - 319s 104ms/step - loss: 1.0305 - accuracy: 0.6983 - val_loss: 1.0951 - val_accuracy: 0.6819
#
# Epoch 00041: saving model to models_attention/1/weights.41-1.10.hdf5
# Epoch 42/50
# 3066/3066 [==============================] - 318s 104ms/step - loss: 1.0166 - accuracy: 0.7048 - val_loss: 1.1008 - val_accuracy: 0.6884
#
# Epoch 00042: saving model to models_attention/1/weights.42-1.10.hdf5
# Epoch 43/50
# 3066/3066 [==============================] - 321s 105ms/step - loss: 1.0182 - accuracy: 0.7006 - val_loss: 1.1083 - val_accuracy: 0.6884
#
# Epoch 00043: saving model to models_attention/1/weights.43-1.11.hdf5
# Epoch 44/50
# 3066/3066 [==============================] - 315s 103ms/step - loss: 1.0122 - accuracy: 0.7038 - val_loss: 1.0861 - val_accuracy: 0.6845
#
# Epoch 00044: saving model to models_attention/1/weights.44-1.09.hdf5
# Epoch 45/50
# 3066/3066 [==============================] - 310s 101ms/step - loss: 0.9940 - accuracy: 0.7127 - val_loss: 1.0907 - val_accuracy: 0.6871
#
# Epoch 00045: saving model to models_attention/1/weights.45-1.09.hdf5
# Epoch 46/50
# 3066/3066 [==============================] - 309s 101ms/step - loss: 0.9917 - accuracy: 0.7146 - val_loss: 1.0703 - val_accuracy: 0.6832
#
# Epoch 00046: saving model to models_attention/1/weights.46-1.07.hdf5
# Epoch 47/50
# 3066/3066 [==============================] - 308s 101ms/step - loss: 0.9835 - accuracy: 0.7120 - val_loss: 1.0570 - val_accuracy: 0.6923
#
# Epoch 00047: saving model to models_attention/1/weights.47-1.06.hdf5
# Epoch 48/50
# 3066/3066 [==============================] - 308s 101ms/step - loss: 0.9781 - accuracy: 0.7202 - val_loss: 1.0664 - val_accuracy: 0.6897
#
# Epoch 00048: saving model to models_attention/1/weights.48-1.07.hdf5
# Epoch 49/50
# 3066/3066 [==============================] - 311s 101ms/step - loss: 0.9727 - accuracy: 0.7202 - val_loss: 1.1012 - val_accuracy: 0.6832
#
# Epoch 00049: saving model to models_attention/1/weights.49-1.10.hdf5
# Epoch 50/50
# 3066/3066 [==============================] - 325s 106ms/step - loss: 0.9764 - accuracy: 0.7156 - val_loss: 1.0763 - val_accuracy: 0.6845
#
# Epoch 00050: saving model to models_attention/1/weights.50-1.08.hdf5

# %%
plot_model(model, to_file='models_attention/1/model_plot.png', 
           show_shapes=True, show_layer_names=True)

# %%
# load model
model = load_model('models_attention/1/weights.47-1.06.hdf5')
# summarize model.
model.summary()
# Out:
# WARNING:tensorflow:From /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/julie/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1499)         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1499, 128)    2944        input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 1499, 256)    263168      embedding_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1499, 1)      257         bidirectional_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1499)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# attention_vect (Activation)     (None, 1499)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 256, 1499)    0           attention_vect[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 1499, 256)    0           repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1499, 256)    0           bidirectional_1[0][0]
#                                                                  permute_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256)          0           multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 9)            2313        lambda_1[0][0]
# ==================================================================================================
# Total params: 268,682
# Trainable params: 268,682
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
score = model.evaluate(x_valid_pad, y_valid_OH, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.0569896511490684
# Test accuracy: 0.692307710647583

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(x_valid_pad)
y_pred_indices = OH_to_label_indices(y_pred)
y_pred_label = indices_to_cat(y_pred_indices)

# %%
conf_mx = confusion_matrix(y_valid, y_pred_label, labels=cat)

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(conf_mx / (conf_mx.max(axis=0)+1), cmap=plt.cm.gray)
fig.colorbar(cax)
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.set_xticklabels([''] + cat,  rotation='vertical')
ax.set_yticklabels([''] + cat)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(conf_mx, cmap=plt.cm.gray)
fig.colorbar(cax)
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.set_xticklabels([''] + cat,  rotation='vertical')
ax.set_yticklabels([''] + cat)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
conf_mx
# Out:
# array([[  0,   1,   0,   0,   0,  11,   0,   1,   0],
#        [  0,  61,   0,   0,   0,  10,   0,   6,  11],
#        [  0,   4,   0,   0,   0,  25,   0,   1,  15],
#        [  0,   5,   0,   0,   0,   3,   0,   1,   2],
#        [  0,  13,   0,   0,   0,  13,   0,   2,   1],
#        [  0,   3,   0,   0,   0, 367,   0,  12,   4],
#        [  0,   8,   0,   0,   0,   3,   0,   1,   2],
#        [  0,   8,   0,   0,   0,  18,   0,  79,   0],
#        [  0,  13,   0,   0,   0,  36,   0,   3,  24]])

# %% [markdown]
# ### Second Model

# %%
max_features = tot_aa + 1
batch_size = 64
#LSTM
units = 128
# Embedding
embedding_size = 128
# Convolution
kernel_size = 5
filters = 64
pool_size = 2

_input = Input(shape=[max_len], dtype='int32')

# get the embedding layer
embedded = Embedding(input_dim=max_features,output_dim=embedding_size,
        input_length=max_len, trainable=True, mask_zero=False)(_input)

conv = Conv1D(filters, kernel_size, padding='valid', activation='relu', 
              strides=1)(embedded)

pool = MaxPooling1D(pool_size=pool_size)(conv)

activations = Bidirectional(LSTM(units, return_sequences=True, 
                                 dropout=0.2, recurrent_dropout=0.2))(pool)

# compute importance for each step
attention = Dense(1, activation='tanh')(activations)
attention = Flatten()(attention)
attention = Activation('softmax', name = 'attention_vect')(attention) # attention_vect for visualization
attention = RepeatVector(units*2)(attention)
attention = Permute([2, 1])(attention)
sent_representation = Multiply()([activations, attention])
sent_representation = Lambda(lambda xin: K.sum(xin, axis=-2), output_shape=(units*2,))(sent_representation)

probabilities = Dense(9, activation='softmax')(sent_representation)

# %%
model = Model(inputs=_input, outputs=probabilities)
model.compile('Nadam', 'categorical_crossentropy', metrics=['accuracy'])
ckpt = ModelCheckpoint(filepath='models_attention/2/weights.{epoch:02d}-{val_loss:.2f}.hdf5', 
                           verbose=1, save_best_only=False)
# Train, train, train
history = model.fit(x_train_pad, y_train_OH, 
                    batch_size=batch_size, epochs=50,
                    class_weight = class_weights,
          validation_data=[x_valid_pad, y_valid_OH], callbacks=[ckpt])
# Out:
# Train on 3066 samples, validate on 767 samples
# Epoch 1/50
# 3066/3066 [==============================] - 175s 57ms/step - loss: 1.6113 - accuracy: 0.5029 - val_loss: 1.5390 - val_accuracy: 0.5033
#
# Epoch 00001: saving model to models_attention/2/weights.01-1.54.hdf5
# Epoch 2/50
# 3066/3066 [==============================] - 158s 52ms/step - loss: 1.5241 - accuracy: 0.5020 - val_loss: 1.4829 - val_accuracy: 0.5267
#
# Epoch 00002: saving model to models_attention/2/weights.02-1.48.hdf5
# Epoch 3/50
# 3066/3066 [==============================] - 157s 51ms/step - loss: 1.4625 - accuracy: 0.5307 - val_loss: 1.4194 - val_accuracy: 0.5241
#
# Epoch 00003: saving model to models_attention/2/weights.03-1.42.hdf5
# Epoch 4/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 1.4399 - accuracy: 0.5411 - val_loss: 1.3705 - val_accuracy: 0.5776
#
# Epoch 00004: saving model to models_attention/2/weights.04-1.37.hdf5
# Epoch 5/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.3741 - accuracy: 0.5590 - val_loss: 1.3422 - val_accuracy: 0.5867
#
# Epoch 00005: saving model to models_attention/2/weights.05-1.34.hdf5
# Epoch 6/50
# 3066/3066 [==============================] - 158s 51ms/step - loss: 1.3254 - accuracy: 0.5851 - val_loss: 1.3030 - val_accuracy: 0.6023
#
# Epoch 00006: saving model to models_attention/2/weights.06-1.30.hdf5
# Epoch 7/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.2888 - accuracy: 0.5926 - val_loss: 1.3231 - val_accuracy: 0.5841
#
# Epoch 00007: saving model to models_attention/2/weights.07-1.32.hdf5
# Epoch 8/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.2613 - accuracy: 0.6050 - val_loss: 1.3960 - val_accuracy: 0.5776
#
# Epoch 00008: saving model to models_attention/2/weights.08-1.40.hdf5
# Epoch 9/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.2430 - accuracy: 0.6119 - val_loss: 1.2806 - val_accuracy: 0.5958
#
# Epoch 00009: saving model to models_attention/2/weights.09-1.28.hdf5
# Epoch 10/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.2248 - accuracy: 0.6164 - val_loss: 1.2207 - val_accuracy: 0.6428
#
# Epoch 00010: saving model to models_attention/2/weights.10-1.22.hdf5
# Epoch 11/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.1795 - accuracy: 0.6458 - val_loss: 1.1636 - val_accuracy: 0.6558
#
# Epoch 00011: saving model to models_attention/2/weights.11-1.16.hdf5
# Epoch 12/50
# 3066/3066 [==============================] - 158s 51ms/step - loss: 1.1471 - accuracy: 0.6562 - val_loss: 1.1817 - val_accuracy: 0.6532
#
# Epoch 00012: saving model to models_attention/2/weights.12-1.18.hdf5
# Epoch 13/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 1.1405 - accuracy: 0.6559 - val_loss: 1.1545 - val_accuracy: 0.6571
#
# Epoch 00013: saving model to models_attention/2/weights.13-1.15.hdf5
# Epoch 14/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.1114 - accuracy: 0.6722 - val_loss: 1.1599 - val_accuracy: 0.6623
#
# Epoch 00014: saving model to models_attention/2/weights.14-1.16.hdf5
# Epoch 15/50
# 3066/3066 [==============================] - 158s 51ms/step - loss: 1.1090 - accuracy: 0.6703 - val_loss: 1.1330 - val_accuracy: 0.6649
#
# Epoch 00015: saving model to models_attention/2/weights.15-1.13.hdf5
# Epoch 16/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 1.0737 - accuracy: 0.6836 - val_loss: 1.1663 - val_accuracy: 0.6480
#
# Epoch 00016: saving model to models_attention/2/weights.16-1.17.hdf5
# Epoch 17/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.0751 - accuracy: 0.6800 - val_loss: 1.1052 - val_accuracy: 0.6714
#
# Epoch 00017: saving model to models_attention/2/weights.17-1.11.hdf5
# Epoch 18/50
# 3066/3066 [==============================] - 157s 51ms/step - loss: 1.0558 - accuracy: 0.6915 - val_loss: 1.0782 - val_accuracy: 0.6832
#
# Epoch 00018: saving model to models_attention/2/weights.18-1.08.hdf5
# Epoch 19/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.0464 - accuracy: 0.6866 - val_loss: 1.1025 - val_accuracy: 0.6767
#
# Epoch 00019: saving model to models_attention/2/weights.19-1.10.hdf5
# Epoch 20/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.0342 - accuracy: 0.6967 - val_loss: 1.0886 - val_accuracy: 0.6741
#
# Epoch 00020: saving model to models_attention/2/weights.20-1.09.hdf5
# Epoch 21/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 1.0241 - accuracy: 0.7025 - val_loss: 1.0816 - val_accuracy: 0.6780
#
# Epoch 00021: saving model to models_attention/2/weights.21-1.08.hdf5
# Epoch 22/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 1.0139 - accuracy: 0.7042 - val_loss: 1.0856 - val_accuracy: 0.6754
#
# Epoch 00022: saving model to models_attention/2/weights.22-1.09.hdf5
# Epoch 23/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 0.9987 - accuracy: 0.7065 - val_loss: 1.0666 - val_accuracy: 0.6649
#
# Epoch 00023: saving model to models_attention/2/weights.23-1.07.hdf5
# Epoch 24/50
# 3066/3066 [==============================] - 157s 51ms/step - loss: 0.9967 - accuracy: 0.6990 - val_loss: 1.0630 - val_accuracy: 0.6845
#
# Epoch 00024: saving model to models_attention/2/weights.24-1.06.hdf5
# Epoch 25/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 0.9753 - accuracy: 0.7179 - val_loss: 1.0774 - val_accuracy: 0.6767
#
# Epoch 00025: saving model to models_attention/2/weights.25-1.08.hdf5
# Epoch 26/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 0.9637 - accuracy: 0.7208 - val_loss: 1.0749 - val_accuracy: 0.6767
#
# Epoch 00026: saving model to models_attention/2/weights.26-1.07.hdf5
# Epoch 27/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 0.9616 - accuracy: 0.7182 - val_loss: 1.0562 - val_accuracy: 0.6910
#
# Epoch 00027: saving model to models_attention/2/weights.27-1.06.hdf5
# Epoch 28/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 0.9392 - accuracy: 0.7202 - val_loss: 1.0714 - val_accuracy: 0.6728
#
# Epoch 00028: saving model to models_attention/2/weights.28-1.07.hdf5
# Epoch 29/50
# 3066/3066 [==============================] - 157s 51ms/step - loss: 0.9318 - accuracy: 0.7273 - val_loss: 1.0683 - val_accuracy: 0.6832
#
# Epoch 00029: saving model to models_attention/2/weights.29-1.07.hdf5
# Epoch 30/50
# 3066/3066 [==============================] - 163s 53ms/step - loss: 0.9228 - accuracy: 0.7215 - val_loss: 1.0562 - val_accuracy: 0.6767
#
# Epoch 00030: saving model to models_attention/2/weights.30-1.06.hdf5
# Epoch 31/50
# 3066/3066 [==============================] - 157s 51ms/step - loss: 0.9258 - accuracy: 0.7250 - val_loss: 1.0692 - val_accuracy: 0.6780
#
# Epoch 00031: saving model to models_attention/2/weights.31-1.07.hdf5
# Epoch 32/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 0.9117 - accuracy: 0.7277 - val_loss: 1.0645 - val_accuracy: 0.6858
#
# Epoch 00032: saving model to models_attention/2/weights.32-1.06.hdf5
# Epoch 33/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 0.8966 - accuracy: 0.7326 - val_loss: 1.0681 - val_accuracy: 0.6910
#
# Epoch 00033: saving model to models_attention/2/weights.33-1.07.hdf5
# Epoch 34/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 0.8841 - accuracy: 0.7387 - val_loss: 1.0484 - val_accuracy: 0.6923
#
# Epoch 00034: saving model to models_attention/2/weights.34-1.05.hdf5
# Epoch 35/50
# 3066/3066 [==============================] - 158s 51ms/step - loss: 0.8697 - accuracy: 0.7407 - val_loss: 1.0497 - val_accuracy: 0.6858
#
# Epoch 00035: saving model to models_attention/2/weights.35-1.05.hdf5
# Epoch 36/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 0.8661 - accuracy: 0.7410 - val_loss: 1.0773 - val_accuracy: 0.6819
#
# Epoch 00036: saving model to models_attention/2/weights.36-1.08.hdf5
# Epoch 37/50
# 3066/3066 [==============================] - 158s 52ms/step - loss: 0.8471 - accuracy: 0.7476 - val_loss: 1.0791 - val_accuracy: 0.6793
#
# Epoch 00037: saving model to models_attention/2/weights.37-1.08.hdf5
# Epoch 38/50
# 3066/3066 [==============================] - 159s 52ms/step - loss: 0.8332 - accuracy: 0.7482 - val_loss: 1.0541 - val_accuracy: 0.6975
#
# Epoch 00038: saving model to models_attention/2/weights.38-1.05.hdf5
# Epoch 39/50
# 3066/3066 [==============================] - 157s 51ms/step - loss: 0.8196 - accuracy: 0.7515 - val_loss: 1.0616 - val_accuracy: 0.6910
#
# Epoch 00039: saving model to models_attention/2/weights.39-1.06.hdf5
# Epoch 40/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 0.8065 - accuracy: 0.7557 - val_loss: 1.0655 - val_accuracy: 0.6975
#
# Epoch 00040: saving model to models_attention/2/weights.40-1.07.hdf5
# Epoch 41/50
# 3066/3066 [==============================] - 157s 51ms/step - loss: 0.8065 - accuracy: 0.7518 - val_loss: 1.0535 - val_accuracy: 0.6910
#
# Epoch 00041: saving model to models_attention/2/weights.41-1.05.hdf5
# Epoch 42/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 0.7894 - accuracy: 0.7586 - val_loss: 1.0889 - val_accuracy: 0.6897
#
# Epoch 00042: saving model to models_attention/2/weights.42-1.09.hdf5
# Epoch 43/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 0.7907 - accuracy: 0.7629 - val_loss: 1.0564 - val_accuracy: 0.6910
#
# Epoch 00043: saving model to models_attention/2/weights.43-1.06.hdf5
# Epoch 44/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 0.7563 - accuracy: 0.7671 - val_loss: 1.0916 - val_accuracy: 0.6845
#
# Epoch 00044: saving model to models_attention/2/weights.44-1.09.hdf5
# Epoch 45/50
# 3066/3066 [==============================] - 155s 51ms/step - loss: 0.7347 - accuracy: 0.7723 - val_loss: 1.1018 - val_accuracy: 0.6936
#
# Epoch 00045: saving model to models_attention/2/weights.45-1.10.hdf5
# Epoch 46/50
# 3066/3066 [==============================] - 156s 51ms/step - loss: 0.7201 - accuracy: 0.7782 - val_loss: 1.0582 - val_accuracy: 0.6871
#
# Epoch 00046: saving model to models_attention/2/weights.46-1.06.hdf5
# Epoch 47/50
# 3066/3066 [==============================] - 164s 54ms/step - loss: 0.6986 - accuracy: 0.7821 - val_loss: 1.0878 - val_accuracy: 0.6871
#
# Epoch 00047: saving model to models_attention/2/weights.47-1.09.hdf5
# Epoch 48/50
# 3066/3066 [==============================] - 180s 59ms/step - loss: 0.7013 - accuracy: 0.7854 - val_loss: 1.0983 - val_accuracy: 0.6819
#
# Epoch 00048: saving model to models_attention/2/weights.48-1.10.hdf5
# Epoch 49/50
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.6800 - accuracy: 0.7795 - val_loss: 1.1116 - val_accuracy: 0.6845
#
# Epoch 00049: saving model to models_attention/2/weights.49-1.11.hdf5
# Epoch 50/50
# 3066/3066 [==============================] - 169s 55ms/step - loss: 0.6655 - accuracy: 0.7834 - val_loss: 1.1300 - val_accuracy: 0.6897
#
# Epoch 00050: saving model to models_attention/2/weights.50-1.13.hdf5

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.show()

# %% [markdown]
# This model train faster but then dramatically overfit

# %%
model = load_model('models_attention/2/weights.34-1.05.hdf5')

# %%
plot_model(model, to_file='models_attention/2/model_plot.png', 
           show_shapes=True, show_layer_names=True)

# %%
y_pred = model.predict(x_valid_pad)
y_pred_indices = OH_to_label_indices(y_pred)
y_pred_label = indices_to_cat(y_pred_indices)

# %%
conf_mx = confusion_matrix(y_valid, y_pred_label, labels=cat)

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(conf_mx / (conf_mx.max(axis=0)+1), cmap=plt.cm.gray)
fig.colorbar(cax)
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.set_xticklabels([''] + cat,  rotation='vertical')
ax.set_yticklabels([''] + cat)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Worse

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(conf_mx, cmap=plt.cm.gray)
fig.colorbar(cax)
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.set_xticklabels([''] + cat,  rotation='vertical')
ax.set_yticklabels([''] + cat)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# This model picked up something for the lysosome, the first model didn't

# %% [markdown]
# ## Model 3
#
# Concatenating several Conv1D

# %%
max_features = tot_aa + 1
batch_size = 32
#LSTM
units = 96
# Embedding
embedding_size = 40
# Convolution
filters = 8
pool_size = 2

_input = Input(shape=[max_len], dtype='int32')

# get the embedding layer
embedded = Embedding(input_dim=max_features,output_dim=embedding_size,
        input_length=max_len, trainable=True, mask_zero=False)(_input)

# Covolution layer of different size

#conv1 = Conv1D(filters, 1, padding='same', activation='relu', 
#              strides=1)(embedded)
conv3 = Conv1D(filters, 3, padding='same', activation='relu', 
              strides=1)(embedded)
pool3 = MaxPooling1D(pool_size=pool_size)(conv3)

conv5 = Conv1D(filters, 5, padding='same', activation='relu', 
              strides=1)(embedded)
pool5 = MaxPooling1D(pool_size=pool_size)(conv5)

conv9 = Conv1D(filters, 9, padding='same', activation='relu', 
              strides=1)(embedded)
pool9 = MaxPooling1D(pool_size=pool_size)(conv9)

conv15 = Conv1D(filters, 15, padding='same', activation='relu', 
              strides=1)(embedded)
pool15 = MaxPooling1D(pool_size=pool_size)(conv15)

# Concatenate the filters
concat = concatenate([pool3, pool5, pool9, pool15], axis=1)

activations = Bidirectional(LSTM(units, return_sequences=False, 
                                 dropout=0.2, recurrent_dropout=0.2))(concat)

# compute importance for each step
#attention = Dense(1, activation='tanh')(activations)
#attention = Flatten()(attention)
#attention = Activation('softmax', name = 'attention_vect')(attention) # attention_vect for visualization
#attention = RepeatVector(units*2)(attention)
#attention = Permute([2, 1])(attention)
#sent_representation = Multiply()([activations, attention])
#sent_representation = Lambda(lambda xin: K.sum(xin, axis=-2), output_shape=(units*2,))(sent_representation)

probabilities = Dense(9, activation='softmax')(activations)

# %%
model = Model(inputs=_input, outputs=probabilities)
model.compile('SGD', 'sparse_categorical_crossentropy', metrics=['accuracy'])
ckpt = ModelCheckpoint(filepath='models_attention/3/weights.{epoch:02d}-{val_loss:.2f}.hdf5', 
                           verbose=1, save_best_only=False)

# %%
plot_model(model, to_file='models_attention/3/model_plot.png', 
           show_shapes=True, show_layer_names=True)

# %%
# Train, train, train
history = model.fit(x_train_pad, y_train_indices, 
                    batch_size=batch_size, epochs=50,
                    class_weight = class_weights,
          validation_data=[x_valid_pad, y_valid_indices], callbacks=[ckpt])
# Out:
# Train on 3066 samples, validate on 767 samples
# Epoch 1/50
# 3066/3066 [==============================] - 391s 128ms/step - loss: 1.9413 - accuracy: 0.4964 - val_loss: 1.7319 - val_accuracy: 0.5033
#
# Epoch 00001: saving model to models_attention/3/weights.01-1.73.hdf5
# Epoch 2/50
# 3066/3066 [==============================] - 382s 125ms/step - loss: 1.6606 - accuracy: 0.5026 - val_loss: 1.6233 - val_accuracy: 0.5033
#
# Epoch 00002: saving model to models_attention/3/weights.02-1.62.hdf5
# Epoch 3/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.6161 - accuracy: 0.5026 - val_loss: 1.6040 - val_accuracy: 0.5033
#
# Epoch 00003: saving model to models_attention/3/weights.03-1.60.hdf5
# Epoch 4/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.6065 - accuracy: 0.5026 - val_loss: 1.5959 - val_accuracy: 0.5033
#
# Epoch 00004: saving model to models_attention/3/weights.04-1.60.hdf5
# Epoch 5/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5971 - accuracy: 0.5026 - val_loss: 1.5924 - val_accuracy: 0.5033
#
# Epoch 00005: saving model to models_attention/3/weights.05-1.59.hdf5
# Epoch 6/50
# 3066/3066 [==============================] - 384s 125ms/step - loss: 1.5952 - accuracy: 0.5026 - val_loss: 1.5912 - val_accuracy: 0.5033
#
# Epoch 00006: saving model to models_attention/3/weights.06-1.59.hdf5
# Epoch 7/50
# 3066/3066 [==============================] - 384s 125ms/step - loss: 1.5923 - accuracy: 0.5026 - val_loss: 1.5906 - val_accuracy: 0.5033
#
# Epoch 00007: saving model to models_attention/3/weights.07-1.59.hdf5
# Epoch 8/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5943 - accuracy: 0.5026 - val_loss: 1.5894 - val_accuracy: 0.5033
#
# Epoch 00008: saving model to models_attention/3/weights.08-1.59.hdf5
# Epoch 9/50
# 3066/3066 [==============================] - 385s 126ms/step - loss: 1.5942 - accuracy: 0.5026 - val_loss: 1.5894 - val_accuracy: 0.5033
#
# Epoch 00009: saving model to models_attention/3/weights.09-1.59.hdf5
# Epoch 10/50
# 3066/3066 [==============================] - 384s 125ms/step - loss: 1.5909 - accuracy: 0.5026 - val_loss: 1.5890 - val_accuracy: 0.5033
#
# Epoch 00010: saving model to models_attention/3/weights.10-1.59.hdf5
# Epoch 11/50
# 3066/3066 [==============================] - 384s 125ms/step - loss: 1.5933 - accuracy: 0.5026 - val_loss: 1.5894 - val_accuracy: 0.5033
#
# Epoch 00011: saving model to models_attention/3/weights.11-1.59.hdf5
# Epoch 12/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5923 - accuracy: 0.5026 - val_loss: 1.5887 - val_accuracy: 0.5033
#
# Epoch 00012: saving model to models_attention/3/weights.12-1.59.hdf5
# Epoch 13/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5904 - accuracy: 0.5026 - val_loss: 1.5889 - val_accuracy: 0.5033
#
# Epoch 00013: saving model to models_attention/3/weights.13-1.59.hdf5
# Epoch 14/50
# 3066/3066 [==============================] - 400s 131ms/step - loss: 1.5929 - accuracy: 0.5026 - val_loss: 1.5887 - val_accuracy: 0.5033
#
# Epoch 00014: saving model to models_attention/3/weights.14-1.59.hdf5
# Epoch 15/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5930 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00015: saving model to models_attention/3/weights.15-1.59.hdf5
# Epoch 16/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5918 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00016: saving model to models_attention/3/weights.16-1.59.hdf5
# Epoch 17/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5921 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00017: saving model to models_attention/3/weights.17-1.59.hdf5
# Epoch 18/50
# 3066/3066 [==============================] - 385s 126ms/step - loss: 1.5904 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00018: saving model to models_attention/3/weights.18-1.59.hdf5
# Epoch 19/50
# 3066/3066 [==============================] - 388s 127ms/step - loss: 1.5903 - accuracy: 0.5026 - val_loss: 1.5888 - val_accuracy: 0.5033
#
# Epoch 00019: saving model to models_attention/3/weights.19-1.59.hdf5
# Epoch 20/50
# 3066/3066 [==============================] - 385s 126ms/step - loss: 1.5927 - accuracy: 0.5026 - val_loss: 1.5887 - val_accuracy: 0.5033
#
# Epoch 00020: saving model to models_attention/3/weights.20-1.59.hdf5
# Epoch 21/50
# 3066/3066 [==============================] - 384s 125ms/step - loss: 1.5911 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00021: saving model to models_attention/3/weights.21-1.59.hdf5
# Epoch 22/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5913 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00022: saving model to models_attention/3/weights.22-1.59.hdf5
# Epoch 23/50
# 3066/3066 [==============================] - 384s 125ms/step - loss: 1.5930 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00023: saving model to models_attention/3/weights.23-1.59.hdf5
# Epoch 24/50
# 3066/3066 [==============================] - 384s 125ms/step - loss: 1.5915 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00024: saving model to models_attention/3/weights.24-1.59.hdf5
# Epoch 25/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5925 - accuracy: 0.5026 - val_loss: 1.5888 - val_accuracy: 0.5033
#
# Epoch 00025: saving model to models_attention/3/weights.25-1.59.hdf5
# Epoch 26/50
# 3066/3066 [==============================] - 384s 125ms/step - loss: 1.5916 - accuracy: 0.5026 - val_loss: 1.5889 - val_accuracy: 0.5033
#
# Epoch 00026: saving model to models_attention/3/weights.26-1.59.hdf5
# Epoch 27/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5906 - accuracy: 0.5026 - val_loss: 1.5887 - val_accuracy: 0.5033
#
# Epoch 00027: saving model to models_attention/3/weights.27-1.59.hdf5
# Epoch 28/50
# 3066/3066 [==============================] - 386s 126ms/step - loss: 1.5914 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00028: saving model to models_attention/3/weights.28-1.59.hdf5
# Epoch 29/50
# 3066/3066 [==============================] - 386s 126ms/step - loss: 1.5920 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00029: saving model to models_attention/3/weights.29-1.59.hdf5
# Epoch 30/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5908 - accuracy: 0.5026 - val_loss: 1.5887 - val_accuracy: 0.5033
#
# Epoch 00030: saving model to models_attention/3/weights.30-1.59.hdf5
# Epoch 31/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5908 - accuracy: 0.5026 - val_loss: 1.5888 - val_accuracy: 0.5033
#
# Epoch 00031: saving model to models_attention/3/weights.31-1.59.hdf5
# Epoch 32/50
# 3066/3066 [==============================] - 385s 125ms/step - loss: 1.5925 - accuracy: 0.5026 - val_loss: 1.5885 - val_accuracy: 0.5033
#
# Epoch 00032: saving model to models_attention/3/weights.32-1.59.hdf5
# Epoch 33/50
# 3066/3066 [==============================] - 387s 126ms/step - loss: 1.5916 - accuracy: 0.5026 - val_loss: 1.5885 - val_accuracy: 0.5033
#
# Epoch 00033: saving model to models_attention/3/weights.33-1.59.hdf5
# Epoch 34/50
# 3066/3066 [==============================] - 383s 125ms/step - loss: 1.5905 - accuracy: 0.5026 - val_loss: 1.5886 - val_accuracy: 0.5033
#
# Epoch 00034: saving model to models_attention/3/weights.34-1.59.hdf5
# Epoch 35/50
# 3066/3066 [==============================] - 385s 125ms/step - loss: 1.5927 - accuracy: 0.5026 - val_loss: 1.5885 - val_accuracy: 0.5033
#
# Epoch 00035: saving model to models_attention/3/weights.35-1.59.hdf5
# Epoch 36/50
# 3066/3066 [==============================] - 384s 125ms/step - loss: 1.5927 - accuracy: 0.5026 - val_loss: 1.5888 - val_accuracy: 0.5033
#
# Epoch 00036: saving model to models_attention/3/weights.36-1.59.hdf5
# Epoch 37/50
# 3066/3066 [==============================] - 386s 126ms/step - loss: 1.5902 - accuracy: 0.5026 - val_loss: 1.5887 - val_accuracy: 0.5033
#
# Epoch 00037: saving model to models_attention/3/weights.37-1.59.hdf5
# Epoch 38/50
# 2336/3066 [=====================>........] - ETA: 1:54 - loss: 1.6010 - accuracy: 0.4987
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-87882437545d> in <module>
#       3                     batch_size=batch_size, epochs=50,
#       4                     class_weight = class_weights,
# ----> 5           validation_data=[x_valid_pad, y_valid_indices], callbacks=[ckpt])
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# Plot training & validation accuracy values
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.show()

# %%
model = load_model('models/3/weights.13-1.15.hdf5')

# %%
plot_model(model, to_file='models/3/model_plot.png', show_shapes=True, show_layer_names=True)

# %%
y_pred = model.predict(x_valid_pad)
y_pred_indices = OH_to_label_indices(y_pred)
y_pred_label = indices_to_cat(y_pred_indices)

# %%
conf_mx = confusion_matrix(y_valid, y_pred_label, labels=cat)

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(conf_mx / (conf_mx.max(axis=0)+1), cmap=plt.cm.gray)
fig.colorbar(cax)
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
ax.set_xticklabels([''] + cat,  rotation='vertical')
ax.set_yticklabels([''] + cat)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
